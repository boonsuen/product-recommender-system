# %% [markdown]
# # Reduce the size of the JSON file
# Since the device that we are using have limited memory, we create this notebook to reduce the file size by removing the column

# %%
#import library to be used in the project
import pandas as pd

#Read the split json file with dataframe
df = pd.read_json(r'C:\Users\Wilson Tan\Downloads\AI assignment\dataset\1.json', lines=True)
df = pd.DataFrame(df)
df
# Out:
#                                                 category  \
# 0      [Electronics, Camera &amp; Photo, Video Survei...
# 1                      [Electronics, Camera &amp; Photo]
# 2      [Electronics, eBook Readers &amp; Accessories,...
# 3      [Electronics, eBook Readers & Accessories, eBo...
# 4      [Electronics, eBook Readers & Accessories, eBo...
# ...                                                  ...
# 99995  [Electronics, Computers & Accessories, Compute...
# 99996  [Electronics, Television & Video, Televisions,...
# 99997   [Electronics, Television & Video, TV-DVD Combos]
# 99998  [Electronics, Computers &amp; Accessories, Com...
# 99999  [Electronics, Camera & Photo, Flashes, Shoe Mo...
#
#                                                    tech1  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 99995
# 99996   class="a-keyvalue prodDetTable" role="present...
# 99997   class="a-keyvalue prodDetTable" role="present...
# 99998
# 99999
#
#                                              description fit  \
# 0      [The following camera brands and models have b...
# 1      [This second edition of the Handbook of Astron...
# 2      [A zesty tale. (Publishers Weekly)<br /><br />...
# 3                                                     []
# 4      [&#8220;sex.lies.murder.fame. is brillllli&#82...
# ...                                                  ...  ..
# 99995  [Kingston is the industry leader in pc memory....
# 99996  [SYLVANIA LC155SL8 15 inch LCD TV. 15 inch LCD...
# 99997  [SYLVANIA CD202SL8 20 inch Pure Flat DVD Combo...
# 99998  [20IN1 CARD READER USB B MALE - WIN/MAC SD/MMC...
# 99999  [<P><B>Kit includes:</B><BR>&diams; 1) Vidpro ...
#
#                                                    title  \
# 0      Genuine Geovision 1 Channel 3rd Party NVR IP S...
# 1      Books "Handbook of Astronomical Image Processi...
# 2                                         One Hot Summer
# 3      Hurray for Hattie Rabbit: Story and pictures (...
# 4                         sex.lies.murder.fame.: A Novel
# ...                                                  ...
# 99995  Kingston HyperX Memory 2GB 1066MHz DDR2 PC2-85...
# 99996                 Sylvania LC155SL8 15-Inch LCD HDTV
# 99997      Sylvania CD202SL8 20-Inch Pure Flat DVD Combo
# 99998  20IN1 Card Reader USB B Male Win/mac Sd/mmc 3....
# 99999  Vidpro VB-6 Rotating Arm Flash Bracket with E-...
#
#                                                 also_buy tech2  \
# 0                                                     []
# 1                                           [0999470906]
# 2                               [0425167798, 039914157X]
# 3                   [0060219521, 0060219580, 0060219394]
# 4                                                     []
# ...                                                  ...   ...
# 99995                                                 []
# 99996                                                 []
# 99997                                                 []
# 99998                                                 []
# 99999  [B005GMWEI8, B00OHDD9V8, B0017U0WM8, B00ENSKUU...
#
#                                               brand  \
# 0                                         GeoVision
# 1                                      33 Books Co.
# 2      Visit Amazon's Carolina Garcia Aguilera Page
# 3               Visit Amazon's Dick Gackenbach Page
# 4                  Visit Amazon's Lolita Files Page
# ...                                             ...
# 99995                           Kingston Technology
# 99996                                      Sylvania
# 99997                                      Sylvania
# 99998                                      StarTech
# 99999                                        VidPro
#
#                                                  feature  \
# 0      [Genuine Geovision 1 Channel NVR IP Software, ...
# 1      [Detailed chapters cover these fundamental top...
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 99995  [2GB Kit (2 x 1GB) 1066MHz DDR2 CL5 (5-5-5-15)...
# 99996  [15 Inch LCD TV, Pixel Resolution XGA /1024x76...
# 99997  [20 inch Tinted 4:3 Pure Flat CRT Display, 181...
# 99998                     [WIN/MAC SD/MMC 3.5 BAY BEIGE]
# 99999  [KIT INCLUDES 2 PRODUCTS -- All BRAND NEW Item...
#
#                                                     rank  \
# 0      [>#3,092 in Tools &amp; Home Improvement &gt; ...
# 1      [>#55,933 in Camera &amp; Photo (See Top 100 i...
# 2                                   3,105,177 in Books (
# 3                                   2,024,298 in Books (
# 4                                   3,778,828 in Books (
# ...                                                  ...
# 99995  [>#19,735 in Electronics > Computers & Accesso...
# 99996  [>#1,291,022 in Electronics (See top 100), >#7...
# 99997  [>#1,572,883 in Electronics (See top 100), >#6...
# 99998  [>#10,156 in Electronics &gt; Accessories &amp...
# 99999  [>#744 in Camera & Photo > Camera & Photo Acce...
#
#                                                also_view            main_cat  \
# 0                                                     []  Camera &amp; Photo
# 1                   [0943396670, 1138055360, 0999470906]  Camera &amp; Photo
# 2                                                     []               Books
# 3                   [0060219521, 0060219475, 0060219394]               Books
# 4                                                     []               Books
# ...                                                  ...                 ...
# 99995                                                 []     All Electronics
# 99996  [B01M1D0KL1, B07H626STV, B005GM6H8G, B007FH7GA...     All Electronics
# 99997                                                 []     All Electronics
# 99998                                                 []     All Electronics
# 99999                                                 []      Camera & Photo
#
#                                             similar_item               date  \
# 0                                                          January 28, 2014
# 1                                                             June 17, 2003
# 2
# 3
# 4
# ...                                                  ...                ...
# 99995                                                          June 1, 2007
# 99996   class="a-bordered a-horizontal-stripes  a-spa...    October 2, 2001
# 99997                                                      February 1, 2007
# 99998                                                     February 13, 2007
# 99999   class="a-bordered a-horizontal-stripes  a-spa...   February 9, 2007
#
#                                                    price        asin  \
# 0                                                 $65.00  0011300000
# 1                                                         0043396828
# 2                                                 $11.49  0060009810
# 3      .a-section.a-spacing-mini{margin-bottom:6px!im...  0060219602
# 4                                                 $13.95  0060786817
# ...                                                  ...         ...
# 99995                                                     B000NDTBCW
# 99996                                                     B000NDRU5W
# 99997                                                     B000NDRU5M
# 99998                                                     B000NDRUDE
# 99999                                              $4.52  B000NDQ6B6
#
#                                                 imageURL  \
# 0      [https://images-na.ssl-images-amazon.com/image...
# 1      [https://images-na.ssl-images-amazon.com/image...
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 99995  [https://images-na.ssl-images-amazon.com/image...
# 99996                                                 []
# 99997  [https://images-na.ssl-images-amazon.com/image...
# 99998  [https://images-na.ssl-images-amazon.com/image...
# 99999  [https://images-na.ssl-images-amazon.com/image...
#
#                                          imageURLHighRes details
# 0      [https://images-na.ssl-images-amazon.com/image...     NaN
# 1      [https://images-na.ssl-images-amazon.com/image...     NaN
# 2                                                     []     NaN
# 3                                                     []     NaN
# 4                                                     []     NaN
# ...                                                  ...     ...
# 99995  [https://images-na.ssl-images-amazon.com/image...      {}
# 99996                                                 []      {}
# 99997  [https://images-na.ssl-images-amazon.com/image...      {}
# 99998  [https://images-na.ssl-images-amazon.com/image...      {}
# 99999  [https://images-na.ssl-images-amazon.com/image...      {}
#
# [100000 rows x 19 columns]

# %%
#Print column
df.columns
# Out:
# Index(['category', 'tech1', 'description', 'fit', 'title', 'also_buy', 'tech2',
#        'brand', 'feature', 'rank', 'also_view', 'main_cat', 'similar_item',
#        'date', 'price', 'asin', 'imageURL', 'imageURLHighRes', 'details'],
#       dtype='object')

# %%
#Drop unneccesary column
df = df.drop(['category', 'tech1', 'description', 'fit', 'also_buy', 'tech2', 'brand', 'feature', 'rank', 
              'also_view', 'similar_item', 'date', 'price', 'imageURL','imageURLHighRes', 'details'], axis=1)
df
# Out:
#                                                    title            main_cat  \
# 0      Genuine Geovision 1 Channel 3rd Party NVR IP S...  Camera &amp; Photo
# 1      Books "Handbook of Astronomical Image Processi...  Camera &amp; Photo
# 2                                         One Hot Summer               Books
# 3      Hurray for Hattie Rabbit: Story and pictures (...               Books
# 4                         sex.lies.murder.fame.: A Novel               Books
# ...                                                  ...                 ...
# 99995  Kingston HyperX Memory 2GB 1066MHz DDR2 PC2-85...     All Electronics
# 99996                 Sylvania LC155SL8 15-Inch LCD HDTV     All Electronics
# 99997      Sylvania CD202SL8 20-Inch Pure Flat DVD Combo     All Electronics
# 99998  20IN1 Card Reader USB B Male Win/mac Sd/mmc 3....     All Electronics
# 99999  Vidpro VB-6 Rotating Arm Flash Bracket with E-...      Camera & Photo
#
#              asin
# 0      0011300000
# 1      0043396828
# 2      0060009810
# 3      0060219602
# 4      0060786817
# ...           ...
# 99995  B000NDTBCW
# 99996  B000NDRU5W
# 99997  B000NDRU5M
# 99998  B000NDRUDE
# 99999  B000NDQ6B6
#
# [100000 rows x 3 columns]

# %%
#to json file with left column
df.to_json('test.json', orient='records', lines=True)

# %%
#Double Checking with the created json file
df = pd.read_json(r'C:\Users\Wilson Tan\Downloads\AI assignment\test.json', lines=True)
df.head()
# Out:
#                                                title            main_cat  \
# 0  Genuine Geovision 1 Channel 3rd Party NVR IP S...  Camera &amp; Photo
# 1  Books "Handbook of Astronomical Image Processi...  Camera &amp; Photo
# 2                                     One Hot Summer               Books
# 3  Hurray for Hattie Rabbit: Story and pictures (...               Books
# 4                     sex.lies.murder.fame.: A Novel               Books
#
#          asin
# 0  0011300000
# 1  0043396828
# 2  0060009810
# 3  0060219602
# 4  0060786817
