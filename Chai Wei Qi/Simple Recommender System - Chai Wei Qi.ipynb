# %% [markdown]
# # Simple Recommender System - Product Recommender

# %% [markdown]
# ## 1. Importing Libraries

# %%
#import library to be used in the project
import numpy as np
import pandas as pd
import html
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.pairwise import linear_kernel
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. File Reading and Features Engineering: products

# %%
# Read the electronic products file
products_dataset_path = r'C:\Users\User\Desktop\product-recommender-system\dataset\subset_meta_Electronics.json'
products = pd.read_json(products_dataset_path, lines=True)

# Output the first 10 rows
products.head(10)
# Out:
#                                             category tech1  \
# 0  [Electronics, Camera &amp; Photo, Video Survei...
# 1                  [Electronics, Camera &amp; Photo]
# 2  [Electronics, eBook Readers &amp; Accessories,...
# 3  [Electronics, eBook Readers & Accessories, eBo...
# 4  [Electronics, eBook Readers & Accessories, eBo...
# 5  [Electronics, eBook Readers &amp; Accessories,...
# 6  [Electronics, eBook Readers & Accessories, eBo...
# 7  [Electronics, Portable Audio & Video, MP3 & MP...
# 8       [Electronics, Headphones, Earbud Headphones]
# 9  [Electronics, Computers &amp; Accessories, Com...
#
#                                          description fit  \
# 0  [The following camera brands and models have b...
# 1  [This second edition of the Handbook of Astron...
# 2  [A zesty tale. (Publishers Weekly)<br /><br />...
# 3                                                 []
# 4  [&#8220;sex.lies.murder.fame. is brillllli&#82...
# 5                                               [, ]
# 6  [GIRL WITH A ONE-TRACK MIND: CONFESSIONS OF TH...
# 7  [Support system: Windows XP/Vsita/7 * SNR: 85d...
# 8  [, <b>True High Definition Sound:</b><br>With ...
# 9                                                 []
#
#                                                title  \
# 0  Genuine Geovision 1 Channel 3rd Party NVR IP S...
# 1  Books "Handbook of Astronomical Image Processi...
# 2                                     One Hot Summer
# 3  Hurray for Hattie Rabbit: Story and pictures (...
# 4                     sex.lies.murder.fame.: A Novel
# 5                                    College Physics
# 6  Girl with a One-track Mind: Confessions of the...
# 7  abcGoodefg&reg; 4GB USB 2.0 Mp3 Music Player w...
# 8  Wireless Bluetooth Headphones Earbuds with Mic...
# 9  Kelby Training DVD: Mastering Blend Modes in A...
#
#                                             also_buy tech2  \
# 0                                                 []
# 1                                       [0999470906]
# 2                           [0425167798, 039914157X]
# 3               [0060219521, 0060219580, 0060219394]
# 4                                                 []
# 5  [0073049557, 0134454170, 1118142063, 007733968...
# 6                                       [0330509691]
# 7  [B01NAJ3KQB, B00WYSPT0C, B00AF40U5G, B00OFVNM4...
# 8                                                 []
# 9                                                 []
#
#                                           brand  \
# 0                                     GeoVision
# 1                                  33 Books Co.
# 2  Visit Amazon's Carolina Garcia Aguilera Page
# 3           Visit Amazon's Dick Gackenbach Page
# 4              Visit Amazon's Lolita Files Page
# 5         Visit Amazon's Alan Giambattista Page
# 6                                      ABBY LEE
# 7                                    Crazy Cart
# 8                               Enter The Arena
# 9                                Kelby Training
#
#                                              feature  \
# 0  [Genuine Geovision 1 Channel NVR IP Software, ...
# 1  [Detailed chapters cover these fundamental top...
# 2                                                 []
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7  [Package Content: 1 x Display MP3 Player 1 x E...
# 8  [Superb Sound Quality: Plays crystal clear aud...
# 9                                                 []
#
#                                                 rank  \
# 0  [>#3,092 in Tools &amp; Home Improvement &gt; ...
# 1  [>#55,933 in Camera &amp; Photo (See Top 100 i...
# 2                               3,105,177 in Books (
# 3                               2,024,298 in Books (
# 4                               3,778,828 in Books (
# 5                               3,330,771 in Books (
# 6                               3,304,037 in Books (
# 7  [>#177,454 in Electronics (See Top 100 in Elec...
# 8  [>#950 in Cell Phones & Accessories (See Top 1...
# 9  [>#932,732 in Computers &amp; Accessories &gt;...
#
#                                            also_view              main_cat  \
# 0                                                 []    Camera &amp; Photo
# 1               [0943396670, 1138055360, 0999470906]    Camera &amp; Photo
# 2                                                 []                 Books
# 3               [0060219521, 0060219475, 0060219394]                 Books
# 4                                                 []                 Books
# 5  [0073512141, 0077339681, 0073049557, 007304956...                 Books
# 6                                       [B0719LDQR1]                 Books
# 7  [B01NAJ3KQB, B00OFVNM4G, B00L41WY8K, B07F34PNP...       All Electronics
# 8                                                 []  Home Audio & Theater
# 9                                                 []             Computers
#
#                                         similar_item               date  \
# 0                                                      January 28, 2014
# 1                                                         June 17, 2003
# 2
# 3
# 4
# 5
# 6
# 7   class="a-bordered a-horizontal-stripes  a-spa...  December 28, 2012
# 8                                                      October 23, 2017
# 9                                                      December 9, 2011
#
#                                                price        asin  \
# 0                                             $65.00  0011300000
# 1                                                     0043396828
# 2                                             $11.49  0060009810
# 3  .a-section.a-spacing-mini{margin-bottom:6px!im...  0060219602
# 4                                             $13.95  0060786817
# 5                                                     0070524076
# 6                                              $4.76  0091912407
# 7                                                     0101635370
# 8                                              $7.99  0132492776
# 9                                                     0132793040
#
#                                             imageURL  \
# 0  [https://images-na.ssl-images-amazon.com/image...
# 1  [https://images-na.ssl-images-amazon.com/image...
# 2                                                 []
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7  [https://images-na.ssl-images-amazon.com/image...
# 8  [https://images-na.ssl-images-amazon.com/image...
# 9  [https://images-na.ssl-images-amazon.com/image...
#
#                                      imageURLHighRes details
# 0  [https://images-na.ssl-images-amazon.com/image...     NaN
# 1  [https://images-na.ssl-images-amazon.com/image...     NaN
# 2                                                 []     NaN
# 3                                                 []     NaN
# 4                                                 []     NaN
# 5                                                 []     NaN
# 6                                                 []     NaN
# 7  [https://images-na.ssl-images-amazon.com/image...     NaN
# 8  [https://images-na.ssl-images-amazon.com/image...     NaN
# 9  [https://images-na.ssl-images-amazon.com/image...     NaN

# %%
print(products.shape)
# output: (rows, columns)
# Out:
# (104802, 19)

# %%
# retrieving column name
products.columns
# Out:
# Index(['category', 'tech1', 'description', 'fit', 'title', 'also_buy', 'tech2',
#        'brand', 'feature', 'rank', 'also_view', 'main_cat', 'similar_item',
#        'date', 'price', 'asin', 'imageURL', 'imageURLHighRes', 'details'],
#       dtype='object')

# %% [markdown]
# ### 2.1 General Cleansing
#
# #### 2.1.1 Drop Unnecessary columns

# %%
# keep: asin, title, brand, main_cat, and price (some columns are for filtering usage)
products = products.drop(columns=['category', 'tech1', 'description', 'fit', 'also_buy', 'tech2',
       'feature', 'rank', 'also_view', 'similar_item', 'date', 'imageURL', 'imageURLHighRes', 'details'], errors='ignore')

products.columns
# Out:
# Index(['title', 'brand', 'main_cat', 'price', 'asin'], dtype='object')

# %%
products = products[['asin', 'title', 'brand', 'price', 'main_cat']]
products.columns = ['product_id', 'product_name', 'brand_or_author', 'price', 'main_category']

# %%
products.head(10)
# Out:
#    product_id                                       product_name  \
# 0  0011300000  Genuine Geovision 1 Channel 3rd Party NVR IP S...
# 1  0043396828  Books "Handbook of Astronomical Image Processi...
# 2  0060009810                                     One Hot Summer
# 3  0060219602  Hurray for Hattie Rabbit: Story and pictures (...
# 4  0060786817                     sex.lies.murder.fame.: A Novel
# 5  0070524076                                    College Physics
# 6  0091912407  Girl with a One-track Mind: Confessions of the...
# 7  0101635370  abcGoodefg&reg; 4GB USB 2.0 Mp3 Music Player w...
# 8  0132492776  Wireless Bluetooth Headphones Earbuds with Mic...
# 9  0132793040  Kelby Training DVD: Mastering Blend Modes in A...
#
#                                 brand_or_author  \
# 0                                     GeoVision
# 1                                  33 Books Co.
# 2  Visit Amazon's Carolina Garcia Aguilera Page
# 3           Visit Amazon's Dick Gackenbach Page
# 4              Visit Amazon's Lolita Files Page
# 5         Visit Amazon's Alan Giambattista Page
# 6                                      ABBY LEE
# 7                                    Crazy Cart
# 8                               Enter The Arena
# 9                                Kelby Training
#
#                                                price         main_category
# 0                                             $65.00    Camera &amp; Photo
# 1                                                       Camera &amp; Photo
# 2                                             $11.49                 Books
# 3  .a-section.a-spacing-mini{margin-bottom:6px!im...                 Books
# 4                                             $13.95                 Books
# 5                                                                    Books
# 6                                              $4.76                 Books
# 7                                                          All Electronics
# 8                                              $7.99  Home Audio & Theater
# 9                                                                Computers

# %% [markdown]
# #### 2.1.2 Remove Duplicates

# %%
products.shape
# Out:
# (104802, 5)

# %%
products.duplicated().sum()
# Out:
# 30368

# %%
products = products.drop_duplicates()

products.shape
# Out:
# (74434, 5)

# %% [markdown]
# #### 2.1.3 Format Strings

# %%
# Defining text cleaning function

def text_cleaning(text):
    # 1. convert any HTML entities in the text to their corresponding characters
    # e.g. &amp; to &, &quot; to ", &reg; to ®
    text = html.unescape(text)
    
    # 2. convert to lower case
    return text.lower()

text = "&amp; &quot &reg;"
cleaned_text = text_cleaning(text)
print(cleaned_text)
# Out:
# & " ®

# %%
# List of columns to be cleaned
cols_to_clean = ['product_id', 'product_name', 'brand_or_author', 'price', 'main_category']

# Apply the text cleaning function to each column
for col in cols_to_clean:
    products[col] = products[col].apply(lambda x: text_cleaning(x))

# %%
products.head(10)
# Out:
#    product_id                                       product_name  \
# 0  0011300000  genuine geovision 1 channel 3rd party nvr ip s...
# 1  0043396828  books "handbook of astronomical image processi...
# 2  0060009810                                     one hot summer
# 3  0060219602  hurray for hattie rabbit: story and pictures (...
# 4  0060786817                     sex.lies.murder.fame.: a novel
# 5  0070524076                                    college physics
# 6  0091912407  girl with a one-track mind: confessions of the...
# 7  0101635370  abcgoodefg® 4gb usb 2.0 mp3 music player with ...
# 8  0132492776  wireless bluetooth headphones earbuds with mic...
# 9  0132793040  kelby training dvd: mastering blend modes in a...
#
#                                 brand_or_author  \
# 0                                     geovision
# 1                                  33 books co.
# 2  visit amazon's carolina garcia aguilera page
# 3           visit amazon's dick gackenbach page
# 4              visit amazon's lolita files page
# 5         visit amazon's alan giambattista page
# 6                                      abby lee
# 7                                    crazy cart
# 8                               enter the arena
# 9                                kelby training
#
#                                                price         main_category
# 0                                             $65.00        camera & photo
# 1                                                           camera & photo
# 2                                             $11.49                 books
# 3  .a-section.a-spacing-mini{margin-bottom:6px!im...                 books
# 4                                             $13.95                 books
# 5                                                                    books
# 6                                              $4.76                 books
# 7                                                          all electronics
# 8                                              $7.99  home audio & theater
# 9                                                                computers

# %% [markdown]
# ### 2.2 Cleaning 'main_category' column

# %%
main_category_df = products.groupby('main_category').size().reset_index(name='count')
main_category_df
# Out:
#                                         main_category  count
# 0   <img src="https://images-na.ssl-images-amazon....     38
# 1   <img src="https://images-na.ssl-images-amazon....    129
# 2   <img src="https://m.media-amazon.com/images/g/...      1
# 3   <img src="https://m.media-amazon.com/images/g/...      1
# 4                                          all beauty     30
# 5                                     all electronics  23269
# 6                                      amazon devices     37
# 7                                         amazon home    428
# 8                                          appliances      2
# 9                               arts, crafts & sewing    110
# 10                                         automotive    417
# 11                                               baby     19
# 12                                              books    335
# 13                                     camera & photo  15138
# 14                                    car electronics   2967
# 15                          cell phones & accessories   3859
# 16                                          computers   7857
# 17                                   gps & navigation    163
# 18                                            grocery      4
# 19                             health & personal care    180
# 20                               home audio & theater  15443
# 21                            industrial & scientific    194
# 22                                        movies & tv      6
# 23                                musical instruments    476
# 24                                    office products    667
# 25                                       pet supplies     30
# 26                       portable audio & accessories    641
# 27                                           software    126
# 28                                  sports & outdoors    830
# 29                           tools & home improvement    806
# 30                                       toys & games    147
# 31                                        video games     84

# %%
# The four image HTML elements are actually belongs to 'amazon fashion'
for i in (main_category_df.loc[0:3, 'main_category']):
    print(i)

# There are total 169 products for amazon fashion
total_af = {'main_category': 'Total', 'count': len(products.loc[products['main_category'].str.contains('amazon fashion')])}
main_category_df.loc[main_category_df['main_category'].str.contains('amazon fashion')].append(total_af, ignore_index=True)
# Out:
# <img src="https://images-na.ssl-images-amazon.com/images/g/01/nav2/images/gui/amazon-fashion-store-new._cb520838675_.png" class="nav-categ-image" alt="amazon fashion" />
# <img src="https://images-na.ssl-images-amazon.com/images/g/01/nav2/images/gui/amazon-fashion-store-new._cb520838675_.png" class="nav-categ-image" alt="amazon fashion"/>
# <img src="https://m.media-amazon.com/images/g/01/nav2/images/gui/amazon-fashion-store-new._cb520838675_.png" class="nav-categ-image" alt="amazon fashion" />
# <img src="https://m.media-amazon.com/images/g/01/nav2/images/gui/amazon-fashion-store-new._cb520838675_.png" class="nav-categ-image" alt="amazon fashion"/>
#                                        main_category  count
# 0  <img src="https://images-na.ssl-images-amazon....     38
# 1  <img src="https://images-na.ssl-images-amazon....    129
# 2  <img src="https://m.media-amazon.com/images/g/...      1
# 3  <img src="https://m.media-amazon.com/images/g/...      1
# 4                                              Total    169

# %%
# assign the four image HTML elements to 'amazon fashion' in main_category_df data frame
main_category_df.loc[main_category_df['main_category'].str.contains('amazon fashion'), 'main_category'] = 'amazon fashion'

main_category_df.groupby('main_category').sum()
# Out:
#                               count
# main_category
# all beauty                       30
# all electronics               23269
# amazon devices                   37
# amazon fashion                  169
# amazon home                     428
# appliances                        2
# arts, crafts & sewing           110
# automotive                      417
# baby                             19
# books                           335
# camera & photo                15138
# car electronics                2967
# cell phones & accessories      3859
# computers                      7857
# gps & navigation                163
# grocery                           4
# health & personal care          180
# home audio & theater          15443
# industrial & scientific         194
# movies & tv                       6
# musical instruments             476
# office products                 667
# pet supplies                     30
# portable audio & accessories    641
# software                        126
# sports & outdoors               830
# tools & home improvement        806
# toys & games                    147
# video games                      84

# %%
# assign the four image HTML elements to 'amazon fashion' in products data frame
products.loc[products['main_category'].str.contains('amazon fashion'), 'main_category'] = 'amazon fashion'

products.groupby('main_category').size().reset_index(name='count')
# Out:
#                    main_category  count
# 0                     all beauty     30
# 1                all electronics  23269
# 2                 amazon devices     37
# 3                 amazon fashion    169
# 4                    amazon home    428
# 5                     appliances      2
# 6          arts, crafts & sewing    110
# 7                     automotive    417
# 8                           baby     19
# 9                          books    335
# 10                camera & photo  15138
# 11               car electronics   2967
# 12     cell phones & accessories   3859
# 13                     computers   7857
# 14              gps & navigation    163
# 15                       grocery      4
# 16        health & personal care    180
# 17          home audio & theater  15443
# 18       industrial & scientific    194
# 19                   movies & tv      6
# 20           musical instruments    476
# 21               office products    667
# 22                  pet supplies     30
# 23  portable audio & accessories    641
# 24                      software    126
# 25             sports & outdoors    830
# 26      tools & home improvement    806
# 27                  toys & games    147
# 28                   video games     84

# %% [markdown]
# ### 2.3 Cleaning 'brand_or_author' column

# %%
# The visit amazon's .... page pattern is actually the author.
pattern = "^visit amazon's (.*) page$"
mask = products['brand_or_author'].str.contains(pattern)
selected_columns = ['brand_or_author', 'main_category']
visit_amazon_pattern = products.loc[mask, selected_columns]

visit_amazon_pattern
# Out:
#                                      brand_or_author main_category
# 2       visit amazon's carolina garcia aguilera page         books
# 3                visit amazon's dick gackenbach page         books
# 4                   visit amazon's lolita files page         books
# 5              visit amazon's alan giambattista page         books
# 10                 visit amazon's claire messud page         books
# ...                                              ...           ...
# 1403                   visit amazon's dan wells page         books
# 1405                 visit amazon's ismael cala page         books
# 1439         visit amazon's maría nuñez quesada page         books
# 68972            visit amazon's karin slaughter page         books
# 104597                 visit amazon's marc levy page         books
#
# [181 rows x 2 columns]

# %%
visit_amazon_pattern.groupby('main_category').size().reset_index(name='count')
# Out:
#   main_category  count
# 0         books    181

# %%
# Clean the brand or author column
def clean_author_string(author_string):
    author_string = author_string.replace("visit amazon's ", "")
    author_string = author_string.replace(" page", "")
    return author_string

products['brand_or_author'] = products['brand_or_author'].apply(clean_author_string)

# %%
# result
products.head(10)
# Out:
#    product_id                                       product_name  \
# 0  0011300000  genuine geovision 1 channel 3rd party nvr ip s...
# 1  0043396828  books "handbook of astronomical image processi...
# 2  0060009810                                     one hot summer
# 3  0060219602  hurray for hattie rabbit: story and pictures (...
# 4  0060786817                     sex.lies.murder.fame.: a novel
# 5  0070524076                                    college physics
# 6  0091912407  girl with a one-track mind: confessions of the...
# 7  0101635370  abcgoodefg® 4gb usb 2.0 mp3 music player with ...
# 8  0132492776  wireless bluetooth headphones earbuds with mic...
# 9  0132793040  kelby training dvd: mastering blend modes in a...
#
#             brand_or_author  \
# 0                 geovision
# 1              33 books co.
# 2  carolina garcia aguilera
# 3           dick gackenbach
# 4              lolita files
# 5         alan giambattista
# 6                  abby lee
# 7                crazy cart
# 8           enter the arena
# 9            kelby training
#
#                                                price         main_category
# 0                                             $65.00        camera & photo
# 1                                                           camera & photo
# 2                                             $11.49                 books
# 3  .a-section.a-spacing-mini{margin-bottom:6px!im...                 books
# 4                                             $13.95                 books
# 5                                                                    books
# 6                                              $4.76                 books
# 7                                                          all electronics
# 8                                              $7.99  home audio & theater
# 9                                                                computers

# %% [markdown]
# ### 2.4 Cleaning 'price' column

# %%
# Clean the 'price' column
def clean_price_string (price_string):
    if price_string.startswith('$'):
        price_string = price_string.replace('$', '')
    else:
        price_string = '0'
    try:
        price_float = float(price_string)
    except ValueError:
        price_float = 0.0
    return price_float

products['price'] = products['price'].apply(clean_price_string)

# %%
# result
products.head(10)
# Out:
#    product_id                                       product_name  \
# 0  0011300000  genuine geovision 1 channel 3rd party nvr ip s...
# 1  0043396828  books "handbook of astronomical image processi...
# 2  0060009810                                     one hot summer
# 3  0060219602  hurray for hattie rabbit: story and pictures (...
# 4  0060786817                     sex.lies.murder.fame.: a novel
# 5  0070524076                                    college physics
# 6  0091912407  girl with a one-track mind: confessions of the...
# 7  0101635370  abcgoodefg® 4gb usb 2.0 mp3 music player with ...
# 8  0132492776  wireless bluetooth headphones earbuds with mic...
# 9  0132793040  kelby training dvd: mastering blend modes in a...
#
#             brand_or_author  price         main_category
# 0                 geovision  65.00        camera & photo
# 1              33 books co.   0.00        camera & photo
# 2  carolina garcia aguilera  11.49                 books
# 3           dick gackenbach   0.00                 books
# 4              lolita files  13.95                 books
# 5         alan giambattista   0.00                 books
# 6                  abby lee   4.76                 books
# 7                crazy cart   0.00       all electronics
# 8           enter the arena   7.99  home audio & theater
# 9            kelby training   0.00             computers

# %% [markdown]
# ## 3. File Reading and Features Engineering: ratings

# %%
# Read the ratings file
ratings_dataset_path = r'C:\Users\User\Desktop\product-recommender-system\dataset\electronic_user.csv'
ratings = pd.read_csv(ratings_dataset_path, names=['user_id', 'product_id','rating','timestamp'], index_col=False)

# Output the first 10 rows
ratings.head(10)
# Out:
#           user_id  product_id  rating   timestamp
# 0   AKM1MP6P0OYPR  0132793040     5.0  1365811200
# 1  A2CX7LUOHB2NDG  0321732944     5.0  1341100800
# 2  A2NWSAGRHCP8N5  0439886341     1.0  1367193600
# 3  A2WNBOD3WNDNKT  0439886341     3.0  1374451200
# 4  A1GI0U4ZRJA8WN  0439886341     1.0  1334707200
# 5  A1QGNMC6O1VW39  0511189877     5.0  1397433600
# 6  A3J3BRHTDRFJ2G  0511189877     2.0  1397433600
# 7  A2TY0BTJOTENPG  0511189877     5.0  1395878400
# 8  A34ATBPOK6HCHY  0511189877     5.0  1395532800
# 9   A89DO69P0XZ27  0511189877     5.0  1395446400

# %%
ratings.columns
# Out:
# Index(['user_id', 'product_id', 'rating', 'timestamp'], dtype='object')

# %% [markdown]
# ### 3.1 Features Engineering
#
# #### 3.1.1 Check Duplicates ( no duplicated rows )

# %%
ratings.shape
# Out:
# (7824482, 4)

# %%
# must check duplicates first before dropping the columns
# because all the four columns, especially the timestamp, are determining the duplication

ratings.duplicated().sum()

# no need to drop duplicates
# no need: ratings = ratings.drop_duplicates()
# Out:
# 0

# %% [markdown]
# #### 3.1.2 Drop Unnecessary Columns

# %%
# keep: product_id and rating  (each rating is valuable only)
# drop: user_id and timestamp
ratings = ratings.drop(columns=['user_id', 'timestamp'], errors='ignore')

ratings.columns
# Out:
# Index(['product_id', 'rating'], dtype='object')

# %%
ratings.head(10)
# Out:
#    product_id  rating
# 0  0132793040     5.0
# 1  0321732944     5.0
# 2  0439886341     1.0
# 3  0439886341     3.0
# 4  0439886341     1.0
# 5  0511189877     5.0
# 6  0511189877     2.0
# 7  0511189877     5.0
# 8  0511189877     5.0
# 9  0511189877     5.0

# %% [markdown]
# #### 3.1.3 Create  'rating_average' and 'rating_count' from 'rating'

# %%
# Calculate the average rating and count of ratings for each product_id
ratings = ratings.groupby('product_id').agg(rating_average=('rating', 'mean'), rating_count=('rating', 'count'))

# use (0,1,2,3,4,5,6 as row indication instead of product_id)
ratings = ratings.reset_index()

ratings.head(10)
# Out:
#    product_id  rating_average  rating_count
# 0  0132793040        5.000000             1
# 1  0321732944        5.000000             1
# 2  0439886341        1.666667             3
# 3  0511189877        4.500000             6
# 4  0528881469        2.851852            27
# 5  0558835155        3.000000             1
# 6  059400232X        5.000000             3
# 7  0594012015        2.000000             8
# 8  0594017343        1.000000             1
# 9  0594017580        3.000000             1

# %%
# Top 10 products with the highest rating_count first then highest rating_average
ratings.sort_values(by=['rating_count','rating_average'], ascending=[False, False]).head(10)
# Out:
#         product_id  rating_average  rating_count
# 308398  B0074BW614        4.491504         18244
# 429572  B00DR0PDNE        3.931020         16454
# 327308  B007WTAJTO        4.424005         14172
# 102804  B0019EHU8G        4.754497         12285
# 296625  B006GWO5WK        4.314657         12226
# 178601  B003ELYQGG        4.392528         11617
# 178813  B003ES5ZUU        4.704749         10276
# 323013  B007R5YDYA        4.690926          9907
# 289775  B00622AG6S        4.420136          9823
# 30276   B0002L5R78        4.448614          9487

# %% [markdown]
# ## 4. Merge 'products' and 'ratings' into 'products_merge'

# %%
# Merge the products and ratings dataframes (keep all the products records)
products_merge = products.merge(ratings, on='product_id', how='left')

# Output the first 10 rows
products_merge.head(10)
# Out:
#    product_id                                       product_name  \
# 0  0011300000  genuine geovision 1 channel 3rd party nvr ip s...
# 1  0043396828  books "handbook of astronomical image processi...
# 2  0060009810                                     one hot summer
# 3  0060219602  hurray for hattie rabbit: story and pictures (...
# 4  0060786817                     sex.lies.murder.fame.: a novel
# 5  0070524076                                    college physics
# 6  0091912407  girl with a one-track mind: confessions of the...
# 7  0101635370  abcgoodefg® 4gb usb 2.0 mp3 music player with ...
# 8  0132492776  wireless bluetooth headphones earbuds with mic...
# 9  0132793040  kelby training dvd: mastering blend modes in a...
#
#             brand_or_author  price         main_category  rating_average  \
# 0                 geovision  65.00        camera & photo             NaN
# 1              33 books co.   0.00        camera & photo             NaN
# 2  carolina garcia aguilera  11.49                 books             NaN
# 3           dick gackenbach   0.00                 books             NaN
# 4              lolita files  13.95                 books             NaN
# 5         alan giambattista   0.00                 books             NaN
# 6                  abby lee   4.76                 books             NaN
# 7                crazy cart   0.00       all electronics             NaN
# 8           enter the arena   7.99  home audio & theater             NaN
# 9            kelby training   0.00             computers             5.0
#
#    rating_count
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           1.0

# %%
products_merge.shape
# Out:
# (74434, 7)

# %% [markdown]
# ### 4.1 Replace NaN

# %%
products_merge.isnull().sum()
# Out:
# product_id             0
# product_name           0
# brand_or_author        0
# price                  0
# main_category          0
# rating_average     73794
# rating_count       73794
# dtype: int64

# %%
products_merge[products_merge['main_category'] == 'all electronics'].count()
# Out:
# product_id         23269
# product_name       23269
# brand_or_author    23269
# price              23269
# main_category      23269
# rating_average       134
# rating_count         134
# dtype: int64

# %%
products_merge[products_merge['main_category'] == 'all electronics'].isnull().sum()

# Too many null rating value of the dataset
# this could be a problem if we want to recommend more products
# But still tolerable if we just want to recommend top few products
# Out:
# product_id             0
# product_name           0
# brand_or_author        0
# price                  0
# main_category          0
# rating_average     23135
# rating_count       23135
# dtype: int64

# %%
products_merge.fillna({'rating_average': 0.0, 'rating_count': 0}, inplace=True)

# %%
products_merge.isnull().sum()
# Out:
# product_id         0
# product_name       0
# brand_or_author    0
# price              0
# main_category      0
# rating_average     0
# rating_count       0
# dtype: int64

# %% [markdown]
# ## 5. Simple Recommender System

# %% [markdown]
# ### 5.1 Simple Rating Sort
#
# ▪ Sorting 'products_merge' by multiple columns.
#
# ▪ Issue: Even if the **rating_count** for a product is very high, but it can have a lower **rating_average**.

# %%
# Top 10 products with the highest rating_count first then highest rating_average
products_merge.sort_values(by=['rating_count','rating_average'], ascending=[False, False]).head(50)
# Out:
#       product_id                                       product_name  \
# 201   0972683275  videosecu 24" long arm tv wall mount low profi...
# 464   1400501466   barnes & noble nook tablet 16gb (color, bntv250)
# 461   1400599997  barnes & noble nook ebook reader (wifi + 3g)[b&w]
# 992   9573212919                                external usb dvd/cd
# 1872  9983891212              premium canon mini hdmi cable 10 feet
# 471   1400532620  barnes and noble nook ebook reader (wifi only)...
# 1003  9625993428  mycarryingcase black mini microphone for iphon...
# 946   8862935293  moleskine kindle cover with reporter-style not...
# 1945  9984984354  garmin nuvi 1450 gps standard red led wall / a...
# 1459  9888002198      universial travel ac wall adapter usb charger
# 1700  9966694544  professional kingston microsdhc 32gb (32 gigab...
# 1996  9985511476  professional kingston microsdhc 4gb card for g...
# 760   3744295508  advanced high speed digital 6 feet hdmi 24k go...
# 470   1400699169  barnes & noble nook hd+ tablet 32gb slate (bnt...
# 1612  9966338926  google nexus 7 tablet charging usb 2.0 data ca...
# 1651  9966569863  professional ultra sandisk microsdhc 32gb (32 ...
# 957   8866139874            moleskine rechargeable booklight, black
# 1916  9983891204  premium 10 feet canon htc-100 upgrade replacem...
# 612   1615527613                barnes & noble bn-adp-h01 power kit
# 1621  9966541551  professional ultra sandisk microsdxc 16gb (16 ...
# 963   8918010656  perfect pixel 30" yamakasi 301 sparta 2560x160...
# 873   7538637400    tomtom cigarette lighter go charger genuine oem
# 40    0528881469  rand mcnally 528881469 7-inch intelliroute tnd...
# 943   8862935307  moleskine kindle dx cover with reporter-style ...
# 460   1400501741                nook hd+ 9" 16gb wi-fi color tablet
# 1948  9984984362  generic standard red led wall/ ac/ home charge...
# 2054  9985609034  premium 50 foot high speed hdmi cable for your...
# 781   5135000011  np-bg1 np-fg1 digital camera replacement batte...
# 1269  9864216155  digilife fold-up compact speakers for apple ip...
# 458   1394860919  mini display port to vga cable adapter for mon...
# 614   1615527672     barnes noble 5010490303 lautner e-reader cover
# 770   3936710058           spreed usb conference speaker microphone
# 877   7562434166  1x colorful silicone keyboard protector skin c...
# 211   0979526191  playboy cover to cover hard drive - every issu...
# 944   8862936826  moleskine folio digital tablet cover for apple...
# 883   7799813393  mygica ezgrabber usb 2.0 video capture, vhs to...
# 1002  9623499043  black silicone skin case for microsoft + sport...
# 1268  9862510447  mini microphone mic recorder for apple ipod / ...
# 634   1616826053    barnes & noble industriell easel e-reader cover
# 848   6875467534  8gb silver hello kitty crystal with necklace u...
# 61    0594033926  barnes & noble dessin leather cover for nook c...
# 783   5342765439  mickey logo crystal usb flash drive with neckl...
# 84    0594451647  barnes & noble hdtv adapter kit for nook hd an...
# 1837  9981739588  premium grade (6 foot) hdmi to mini hdmi cable...
# 72    0594481902  barnes & noble ov/hb universal power kit for n...
# 1747  9967229314  professional mobile ultra sandisck microsdxc 6...
# 754   3126743692                     8gb owl design usb flash drive
# 2113  9985602560  premium 6 feet samsung galaxy tab mini hdmi ca...
# 1266  9862376740  stylish zebra giraffe pattern landscape style ...
# 865   7507825604  bargain cable db9 female / db9 female null mod...
#
#                                      brand_or_author  price  \
# 201                                        videosecu  34.99
# 464                                   barnes & noble   0.00
# 461                                   barnes & noble   0.00
# 992                                        epartsdom  14.86
# 1872                                           lasus   0.00
# 471                                   barnes & noble   0.00
# 1003                                  mycarryingcase   2.08
# 946                                        moleskine   0.00
# 1945                                          garmin   9.95
# 1459                                  mycarryingcase   7.24
# 1700                                        kingston   9.20
# 1996                                        kingston   0.00
# 760                                               le   4.72
# 470                                   barnes & noble  89.55
# 1612                                     a days tech   5.90
# 1651                                         sandisk   9.43
# 957                                        moleskine  17.40
# 1916                                     a days tech   6.68
# 612                                   barnes & noble  58.88
# 1621                                         sandisk   9.50
# 963                                         yamakasi   0.00
# 873                                           tomtom   0.00
# 40                                      rand mcnally   0.00
# 943                                        moleskine   0.00
# 460                                   barnes & noble   0.00
# 1948                                         unknown   0.00
# 2054                                     a days tech  11.99
# 781                              good deals everyday   0.00
# 1269                                         dekcell   0.00
# 458                                         judy dee   3.92
# 614                                   barnes & noble  22.49
# 770                            spreed online meeting   0.00
# 877                                          casebuy   0.00
# 211   playboy enterprises - bondi digital publishing   0.00
# 944                                        moleskine  84.18
# 883                                           mygica   0.00
# 1002                                  mycarryingcase   0.00
# 1268                                         generic   0.00
# 634                                   barnes & noble   0.00
# 848                                      hello kitty   0.00
# 61                                    barnes & noble   0.00
# 783                                           disney   0.00
# 84                                    barnes & noble   1.46
# 1837                                     a days tech   0.00
# 72                                    barnes & noble   0.00
# 1747                                        sandisck   0.00
# 754                                            panda   0.00
# 2113                                     a days tech   0.00
# 1266                                     charter inc   0.00
# 865                                             stsi   5.05
#
#                      main_category  rating_average  rating_count
# 201                all electronics        4.470980        1051.0
# 464                      computers        3.560000         250.0
# 461                all electronics        3.490991         222.0
# 992                      computers        3.879397         199.0
# 1872               all electronics        4.442529         174.0
# 471                all electronics        3.684211         171.0
# 1003  portable audio & accessories        3.420168         119.0
# 946                 amazon devices        3.915789          95.0
# 1945              gps & navigation        3.075949          79.0
# 1459               all electronics        3.971429          70.0
# 1700                     computers        3.771429          70.0
# 1996                     computers        4.645161          62.0
# 760           home audio & theater        4.416667          60.0
# 470                      computers        4.319149          47.0
# 1612                     computers        2.761905          42.0
# 1651                     computers        4.205128          39.0
# 957                office products        2.605263          38.0
# 1916          home audio & theater        4.457143          35.0
# 612   portable audio & accessories        3.875000          32.0
# 1621                     computers        4.451613          31.0
# 963                      computers        4.724138          29.0
# 873               gps & navigation        4.107143          28.0
# 40                 all electronics        2.851852          27.0
# 943                 amazon devices        4.038462          26.0
# 460                      computers        3.846154          26.0
# 1948              gps & navigation        2.576923          26.0
# 2054               all electronics        4.360000          25.0
# 781                 camera & photo        3.958333          24.0
# 1269                     computers        3.875000          24.0
# 458                      computers        3.782609          23.0
# 614   portable audio & accessories        4.809524          21.0
# 770                      computers        3.809524          21.0
# 877                      computers        4.050000          20.0
# 211                      computers        3.550000          20.0
# 944                all electronics        3.000000          20.0
# 883           home audio & theater        3.000000          19.0
# 1002               all electronics        4.222222          18.0
# 1268  portable audio & accessories        3.777778          18.0
# 634   portable audio & accessories        4.588235          17.0
# 848                      computers        4.529412          17.0
# 61    portable audio & accessories        4.533333          15.0
# 783                      computers        3.666667          15.0
# 84            home audio & theater        4.357143          14.0
# 1837               all electronics        4.615385          13.0
# 72                       computers        4.384615          13.0
# 1747                     computers        4.333333          12.0
# 754                      computers        3.916667          12.0
# 2113               all electronics        2.166667          12.0
# 1266                     computers        3.454545          11.0
# 865                      computers        4.800000          10.0

# %% [markdown]
# ### 5.2 Weighted Rating
#
# ▪ A *weighted rating* that takes into account the **rating_average** and the **rating_count** it has accumulated.
#
# ▪ We can calculate the Weighted Rating Score into a new 'score' column.
#
# ▪ The formula of weighted rating is as follows:
#
# <img src="weighted_rating.png" width="600">
#
# \>>> **v** is the number of rating for the product (represented by **rating_count**)
#
# \>>> **m** is the **minimum rating count** required to be listed in the chart (to be calculated)
#
# \>>> **R** is the average rating of the product (represented by **rating_average**)
#
# \>>> **C** is the **mean of rating average** across the whole dataframe (to be calculated)

# %%
# describe() - can analyse the dataframe overallly
# C can be viewed using describe().

products_merge.describe()

# From the output:
# get C: mean of **rating_average** of product
# Out:
#               price  rating_average  rating_count
# count  74434.000000    74434.000000  74434.000000
# mean       8.630102        0.034153      0.061249
# std       38.781412        0.385522      4.318074
# min        0.000000        0.000000      0.000000
# 25%        0.000000        0.000000      0.000000
# 50%        0.000000        0.000000      0.000000
# 75%        3.760000        0.000000      0.000000
# max      999.990000        5.000000   1051.000000

# %%
# C, the mean of rating average across the whole dataframe
C = products_merge['rating_average'].mean()
C
# Out:
# 0.03415334719903093

# %%
# m, minimum rating count required to be listed in the chart

# consider the 99.5th percentile.

# for a product to be recommended, it must have more votes than at least 99.5% of the products.

m = products_merge['rating_count'].quantile(0.995) 
m
# Out:
# 1.0

# %%
q_products = products_merge.copy().loc[products_merge['rating_count'] >= m]

q_products
# Out:
#       product_id                                       product_name  \
# 9     0132793040  kelby training dvd: mastering blend modes in a...
# 23    0321732944  kelby training dvd: adobe photoshop cs5 crash ...
# 37    0511189877  clikr-5 time warner cable remote control ur5u-...
# 40    0528881469  rand mcnally 528881469 7-inch intelliroute tnd...
# 47    0558835155  polaroid pbm2200 pc / gaming stereo headphones...
# ...          ...                                                ...
# 2271  9990950636  premium 6 foot high speed hdmi cable for your ...
# 2272  9991330038  mobile action ma-8072p usb data cable software...
# 2274  9991546634  cellet microsd 4gb memory card for palm pre ph...
# 2278  9991549358  cellet microsd 4gb memory card for samsung sgh...
# 2280  9991535896  cellet microsd 2gb memory card for samsung a77...
#
#      brand_or_author  price    main_category  rating_average  rating_count
# 9     kelby training   0.00        computers        5.000000           1.0
# 23    kelby training   0.00        computers        5.000000           1.0
# 37               urc   0.00  all electronics        4.500000           6.0
# 40      rand mcnally   0.00  all electronics        2.851852          27.0
# 47          polaroid   0.00  all electronics        3.000000           1.0
# ...              ...    ...              ...             ...           ...
# 2271     a days tech   4.25  all electronics        4.285714           7.0
# 2272   mobile excess   0.00        computers        1.000000           1.0
# 2274          cellet   0.00        computers        1.000000           1.0
# 2278          cellet   0.00        computers        5.000000           1.0
# 2280          cellet   0.00        computers        5.000000           1.0
#
# [640 rows x 7 columns]

# %%
# Function that computes the weighted rating of each product
def weighted_rating(x, m = m, C = C):
    
    v = x['rating_count']
    R = x['rating_average']
    
    # Calculation based on the IMDB formula
    return (v / (v + m) * R) + (m / (m + v) * C)

# %%
q_products['score'] = q_products.apply(weighted_rating, axis=1)

q_products.head(10)
# Out:
#     product_id                                       product_name  \
# 9   0132793040  kelby training dvd: mastering blend modes in a...
# 23  0321732944  kelby training dvd: adobe photoshop cs5 crash ...
# 37  0511189877  clikr-5 time warner cable remote control ur5u-...
# 40  0528881469  rand mcnally 528881469 7-inch intelliroute tnd...
# 47  0558835155  polaroid pbm2200 pc / gaming stereo headphones...
# 52  0594012015   barnes & noble nook power kit in carbon bnadpn31
# 53  0594017580          jonathan adler punctuation cover in black
# 56  0594033896       nook color clear screen protector kit 2-pack
# 58  0594287995  kate spade rain or shine magazine cover for no...
# 59  0594017343  barnes noble nook simple touch reader brnv300+...
#
#      brand_or_author  price                 main_category  rating_average  \
# 9     kelby training   0.00                     computers        5.000000
# 23    kelby training   0.00                     computers        5.000000
# 37               urc   0.00               all electronics        4.500000
# 40      rand mcnally   0.00               all electronics        2.851852
# 47          polaroid   0.00               all electronics        3.000000
# 52    barnes & noble   0.00               all electronics        2.000000
# 53   barnes & nobles   8.99  portable audio & accessories        3.000000
# 56    barnes & noble   1.96  portable audio & accessories        4.400000
# 58    barnes & noble   0.00               all electronics        5.000000
# 59  barnes and noble   0.00     cell phones & accessories        1.000000
#
#     rating_count     score
# 9            1.0  2.517077
# 23           1.0  2.517077
# 37           6.0  3.862022
# 40          27.0  2.751220
# 47           1.0  1.517077
# 52           8.0  1.781573
# 53           1.0  1.517077
# 56           5.0  3.672359
# 58           1.0  2.517077
# 59           1.0  0.517077

# %% [markdown]
# ### 5.3 Result using Weighted Rating

# %% [markdown]
# #### 5.3.1 Recommending Top 20 Products
#
# ▪ Sort q_proucts in descending order based on the score feature column.
#
# ▪ Output the product_name, main_category, brand_or_author, price, rating_average, rating_count, and weighted rating (score) of the top 20 products.

# %%
# Sort products based on 'score' and recommend the top 20 products
top_20_proucts = q_products.sort_values('score', ascending = False).head(20).reset_index()

columns = ['product_name', 'main_category','brand_or_author', 'price',  'rating_average', 'rating_count', 'score']
top_20_proucts = top_20_proucts [columns]

top_20_proucts.index = top_20_proucts.index + 1

top_20_proucts
# Out:
#                                          product_name  \
# 1      barnes noble 5010490303 lautner e-reader cover
# 2   professional kingston microsdhc 4gb card for g...
# 3   perfect pixel 30" yamakasi 301 sparta 2560x160...
# 4   videosecu 24" long arm tv wall mount low profi...
# 5               premium canon mini hdmi cable 10 feet
# 6   bargain cable db9 female / db9 female null mod...
# 7   advanced high speed digital 6 feet hdmi 24k go...
# 8       db9 male / db9 female null modem mini adapter
# 9     barnes & noble industriell easel e-reader cover
# 10  premium 10 feet canon htc-100 upgrade replacem...
# 11  professional ultra sandisk microsdxc 16gb (16 ...
# 12  kingston professional microsdhc 8gb (8 gigabyt...
# 13        barnes & noble emerson quote e-reader cover
# 14  professional kingston microsdhc 8gb (8 gigabyt...
# 15  premium grade (6 foot) hdmi to mini hdmi cable...
# 16  8gb silver hello kitty crystal with necklace u...
# 17  barnes & noble dessin leather cover for nook c...
# 18  barnes & noble nook hd+ tablet 32gb slate (bnt...
# 19  professional kingston microsdhc 4gb (4 gigabyt...
# 20  premium 50 foot high speed hdmi cable for your...
#
#                    main_category brand_or_author  price  rating_average  \
# 1   portable audio & accessories  barnes & noble  22.49        4.809524
# 2                      computers        kingston   0.00        4.645161
# 3                      computers        yamakasi   0.00        4.724138
# 4                all electronics       videosecu  34.99        4.470980
# 5                all electronics           lasus   0.00        4.442529
# 6                      computers            stsi   5.05        4.800000
# 7           home audio & theater              le   4.72        4.416667
# 8           home audio & theater   bargain cable   4.85        4.875000
# 9   portable audio & accessories  barnes & noble   0.00        4.588235
# 10          home audio & theater     a days tech   6.68        4.457143
# 11                     computers         sandisk   9.50        4.451613
# 12                     computers        kingston   9.37        4.777778
# 13  portable audio & accessories  barnes & noble  29.99        4.777778
# 14                     computers        kingston   7.90        5.000000
# 15               all electronics     a days tech   0.00        4.615385
# 16                     computers     hello kitty   0.00        4.529412
# 17  portable audio & accessories  barnes & noble   0.00        4.533333
# 18                     computers  barnes & noble  89.55        4.319149
# 19                     computers        kingston   0.00        4.750000
# 20               all electronics     a days tech  11.99        4.360000
#
#     rating_count     score
# 1           21.0  4.592462
# 2           62.0  4.571971
# 3           29.0  4.567805
# 4         1051.0  4.466763
# 5          174.0  4.417338
# 6           10.0  4.366741
# 7           60.0  4.344822
# 8            8.0  4.337128
# 9           17.0  4.335231
# 10          35.0  4.334282
# 11          31.0  4.313567
# 12           9.0  4.303415
# 13           9.0  4.303415
# 14           6.0  4.290593
# 15          13.0  4.288154
# 16          17.0  4.279675
# 17          15.0  4.252135
# 18          47.0  4.229878
# 19           8.0  4.226017
# 20          25.0  4.193621

# %% [markdown]
# #### 5.3.2 Recommending Top 20 Products According to product_name

# %%
# E.g. cable
product_name = input("Enter the product name : ")
# Out:
# Enter the product name : cable

# %%
top_20_product_name = q_products[q_products['product_name'].str.contains(product_name.lower())]

top_20_product_name = top_20_product_name [columns].sort_values('score', ascending = False).reset_index()
top_20_product_name.index = top_20_product_name.index + 1

top_20_product_name.head(20)
# Out:
#     index                                       product_name  \
# 1    1872              premium canon mini hdmi cable 10 feet
# 2     865  bargain cable db9 female / db9 female null mod...
# 3     760  advanced high speed digital 6 feet hdmi 24k go...
# 4    1916  premium 10 feet canon htc-100 upgrade replacem...
# 5    1837  premium grade (6 foot) hdmi to mini hdmi cable...
# 6    2054  premium 50 foot high speed hdmi cable for your...
# 7     761  mobile excess advanced high speed digital 10 f...
# 8     882  monster equivalent hdmi 1000hd ultra-high spee...
# 9    1868  premium 6 ft canon htc100 upgrade replacement ...
# 10     37  clikr-5 time warner cable remote control ur5u-...
# 11   2028  coby mp620 4gb mp3 and video player! charging ...
# 12   1877  premium 10 ft panasonic rp-cdhm30-k mini 1.3c ...
# 13   2271  premium 6 foot high speed hdmi cable for your ...
# 14   1854  premium 6 foot high speed hdmi cable for your ...
# 15    458  mini display port to vga cable adapter for mon...
# 16   1838  premium 6 foot high speed hdmi cable for your ...
# 17   1965  professional 25 ft high speed hdmi cable for y...
# 18   1857  advanced high speed digital 15 ft hdmi 24k gol...
# 19   1970  garmin nuvi 1300 gps charging usb 2.0 data cab...
# 20   2228  premium 6 ft veho muvi hd camcorder mini hdmi ...
#
#            main_category brand_or_author  price  rating_average  rating_count  \
# 1        all electronics           lasus   0.00        4.442529         174.0
# 2              computers            stsi   5.05        4.800000          10.0
# 3   home audio & theater              le   4.72        4.416667          60.0
# 4   home audio & theater     a days tech   6.68        4.457143          35.0
# 5        all electronics     a days tech   0.00        4.615385          13.0
# 6        all electronics     a days tech  11.99        4.360000          25.0
# 7        all electronics   mobile excess   9.62        5.000000           5.0
# 8        all electronics         monster   6.00        4.625000           8.0
# 9   home audio & theater     a days tech   4.28        4.555556           9.0
# 10       all electronics             urc   0.00        4.500000           6.0
# 11             computers     a days tech   9.75        5.000000           3.0
# 12       all electronics     a days tech   0.00        5.000000           3.0
# 13       all electronics     a days tech   4.25        4.285714           7.0
# 14       all electronics     a days tech   0.00        4.400000           5.0
# 15             computers        judy dee   3.92        3.782609          23.0
# 16  home audio & theater     a days tech   0.00        3.857143           7.0
# 17       all electronics     a days tech   0.00        5.000000           2.0
# 18       all electronics     a days tech   5.95        4.000000           4.0
# 19             computers           lasus   6.97        4.000000           4.0
# 20       all electronics     a days tech   0.00        4.500000           2.0
#
#        score
# 1   4.417338
# 2   4.366741
# 3   4.344822
# 4   4.334282
# 5   4.288154
# 6   4.193621
# 7   4.172359
# 8   4.114906
# 9   4.103415
# 10  3.862022
# 11  3.758538
# 12  3.758538
# 13  3.754269
# 14  3.672359
# 15  3.626423
# 16  3.379269
# 17  3.344718
# 18  3.206831
# 19  3.206831
# 20  3.011384

# %% [markdown]
# #### 5.3.3 Recommending Top 20 Products According to main_category

# %%
# e.g computer
main_category = input("Enter the main category : ")
# Out:
# Enter the main category : computer

# %%
top_20_main_category = q_products[q_products['main_category'].str.contains(main_category.lower())]

top_20_main_category = top_20_main_category [columns].sort_values('score', ascending = False).reset_index()
top_20_main_category.index = top_20_main_category.index + 1

top_20_main_category.head(20)
# Out:
#     index                                       product_name main_category  \
# 1    1996  professional kingston microsdhc 4gb card for g...     computers
# 2     963  perfect pixel 30" yamakasi 301 sparta 2560x160...     computers
# 3     865  bargain cable db9 female / db9 female null mod...     computers
# 4    1621  professional ultra sandisk microsdxc 16gb (16 ...     computers
# 5    1726  kingston professional microsdhc 8gb (8 gigabyt...     computers
# 6    1618  professional kingston microsdhc 8gb (8 gigabyt...     computers
# 7     848  8gb silver hello kitty crystal with necklace u...     computers
# 8     470  barnes & noble nook hd+ tablet 32gb slate (bnt...     computers
# 9    1986  professional kingston microsdhc 4gb (4 gigabyt...     computers
# 10   1557  professional kingston microsdhc 32gb (32 gigab...     computers
# 11   1547  professional kingston microsdhc 16gb (16 gigab...     computers
# 12   1651  professional ultra sandisk microsdhc 32gb (32 ...     computers
# 13     72  barnes & noble ov/hb universal power kit for n...     computers
# 14   2093  professional kingston microsdhc 16gb (16 gigab...     computers
# 15   2046                              lg octane vn530 phone     computers
# 16   2035                            kingston microsdhc 16gb     computers
# 17   1677  professional kingston microsdhc 16gb (16 gigab...     computers
# 18   1747  professional mobile ultra sandisck microsdxc 6...     computers
# 19    992                                external usb dvd/cd     computers
# 20    877  1x colorful silicone keyboard protector skin c...     computers
#
#    brand_or_author  price  rating_average  rating_count     score
# 1         kingston   0.00        4.645161          62.0  4.571971
# 2         yamakasi   0.00        4.724138          29.0  4.567805
# 3             stsi   5.05        4.800000          10.0  4.366741
# 4          sandisk   9.50        4.451613          31.0  4.313567
# 5         kingston   9.37        4.777778           9.0  4.303415
# 6         kingston   7.90        5.000000           6.0  4.290593
# 7      hello kitty   0.00        4.529412          17.0  4.279675
# 8   barnes & noble  89.55        4.319149          47.0  4.229878
# 9         kingston   0.00        4.750000           8.0  4.226017
# 10        kingston   9.50        4.833333           6.0  4.147736
# 11        kingston   8.18        4.555556           9.0  4.103415
# 12         sandisk   9.43        4.205128          39.0  4.100854
# 13  barnes & noble   0.00        4.384615          13.0  4.073868
# 14        kingston   0.00        5.000000           4.0  4.006831
# 15        kingston   0.00        5.000000           4.0  4.006831
# 16        kingston  33.97        4.571429           7.0  4.004269
# 17        kingston   7.57        4.400000          10.0  4.003105
# 18        sandisck   0.00        4.333333          12.0  4.002627
# 19       epartsdom  14.86        3.879397         199.0  3.860171
# 20         casebuy   0.00        4.050000          20.0  3.858769

# %% [markdown]
# #### 5.3.4 Recommending Top 20 Products According to brand_or_author

# %%
# e.g. barnes
brand_or_author = input("Enter the brand or author : ")
# Out:
# Enter the brand or author : barnes

# %%
top_20_brand_or_author = q_products[q_products['brand_or_author'].str.contains(brand_or_author.lower())]

top_20_brand_or_author = top_20_brand_or_author [columns].sort_values('score', ascending = False).reset_index()
top_20_brand_or_author.index = top_20_brand_or_author.index + 1

top_20_brand_or_author.head(20)
# Out:
#     index                                       product_name  \
# 1     614     barnes noble 5010490303 lautner e-reader cover
# 2     634    barnes & noble industriell easel e-reader cover
# 3     622        barnes & noble emerson quote e-reader cover
# 4      61  barnes & noble dessin leather cover for nook c...
# 5     470  barnes & noble nook hd+ tablet 32gb slate (bnt...
# 6      72  barnes & noble ov/hb universal power kit for n...
# 7      84  barnes & noble hdtv adapter kit for nook hd an...
# 8      63  barnes & noble power adapter for nook simple t...
# 9     612                barnes & noble bn-adp-h01 power kit
# 10    460                nook hd+ 9" 16gb wi-fi color tablet
# 11    638  barnes & noble nook nk01110018 lyra e-reader l...
# 12     56       nook color clear screen protector kit 2-pack
# 13    471  barnes and noble nook ebook reader (wifi only)...
# 14    464   barnes & noble nook tablet 16gb (color, bntv250)
# 15     95  barnes & noble nook color & tablet anti-glare ...
# 16    461  barnes & noble nook ebook reader (wifi + 3g)[b&w]
# 17    105                              nook vara stylus: red
# 18     60      barnes & noble 7" lautner chocolate nook case
# 19    627  barnes & noble nook 2nd edition oliver cover b...
# 20    637           lyra light in black for nook 2nd edition
#
#                    main_category brand_or_author  price  rating_average  \
# 1   portable audio & accessories  barnes & noble  22.49        4.809524
# 2   portable audio & accessories  barnes & noble   0.00        4.588235
# 3   portable audio & accessories  barnes & noble  29.99        4.777778
# 4   portable audio & accessories  barnes & noble   0.00        4.533333
# 5                      computers  barnes & noble  89.55        4.319149
# 6                      computers  barnes & noble   0.00        4.384615
# 7           home audio & theater  barnes & noble   1.46        4.357143
# 8                all electronics  barnes & noble   0.00        4.666667
# 9   portable audio & accessories  barnes & noble  58.88        3.875000
# 10                     computers  barnes & noble   0.00        3.846154
# 11  portable audio & accessories  barnes & noble   0.00        4.111111
# 12  portable audio & accessories  barnes & noble   1.96        4.400000
# 13               all electronics  barnes & noble   0.00        3.684211
# 14                     computers  barnes & noble   0.00        3.560000
# 15  portable audio & accessories  barnes & noble  14.95        4.666667
# 16               all electronics  barnes & noble   0.00        3.490991
# 17                     computers  barnes & noble   0.00        5.000000
# 18               all electronics  barnes & noble   0.00        5.000000
# 19     cell phones & accessories  barnes & noble  18.95        5.000000
# 20               all electronics  barnes & noble   0.00        4.333333
#
#     rating_count     score
# 1           21.0  4.592462
# 2           17.0  4.335231
# 3            9.0  4.303415
# 4           15.0  4.252135
# 5           47.0  4.229878
# 6           13.0  4.073868
# 7           14.0  4.068944
# 8            6.0  4.004879
# 9           32.0  3.758611
# 10          26.0  3.704969
# 11           9.0  3.703415
# 12           5.0  3.672359
# 13         171.0  3.662989
# 14         250.0  3.545953
# 15           3.0  3.508538
# 16         222.0  3.475489
# 17           2.0  3.344718
# 18           2.0  3.344718
# 19           2.0  3.344718
# 20           3.0  3.258538

# %% [markdown]
# #### 5.3.5 Recommending Top 20 Products According to price range

# %%
# e.g. 10, 100
min_price = int(input("Enter the minimum price : "))
max_price = int(input("Enter the maximum price : "))
# Out:
# Enter the minimum price : 10
# Enter the maximum price : 100

# %%
top_20_within_price_range = q_products[(q_products['price'] >= min_price) & (q_products['price'] <= max_price)]

top_20_within_price_range = top_20_within_price_range [columns].sort_values('score', ascending = False).reset_index()
top_20_within_price_range.index = top_20_within_price_range.index + 1

top_20_within_price_range.head(20)
# Out:
#     index                                       product_name  \
# 1     614     barnes noble 5010490303 lautner e-reader cover
# 2     201  videosecu 24" long arm tv wall mount low profi...
# 3     622        barnes & noble emerson quote e-reader cover
# 4     470  barnes & noble nook hd+ tablet 32gb slate (bnt...
# 5    2054  premium 50 foot high speed hdmi cable for your...
# 6    2035                            kingston microsdhc 16gb
# 7     992                                external usb dvd/cd
# 8     612                barnes & noble bn-adp-h01 power kit
# 9     446  bluetooth headphones, bluetooth v4.1+edr wirel...
# 10   1732  professional ultra sandisk 32gb microsdhc veri...
# 11     95  barnes & noble nook color & tablet anti-glare ...
# 12    816  np-bk1 npbk1 type k li-ion battery charger for...
# 13   1420  professional ultra sandisk 64gb microsdxc card...
# 14   1387  professional ultra sandisk 64gb microsdxc card...
# 15   1611  professional ultra sandisk microsdxc 32gb (32 ...
# 16   2232  professional mobile ultra sandisck microsdxc 6...
# 17    627  barnes & noble nook 2nd edition oliver cover b...
# 18    941  professional led video light panel with barn d...
# 19   1378  professional ultra sandisk 64gb microsdxc card...
# 20   2049                             google nexus one phone
#
#                    main_category brand_or_author  price  rating_average  \
# 1   portable audio & accessories  barnes & noble  22.49        4.809524
# 2                all electronics       videosecu  34.99        4.470980
# 3   portable audio & accessories  barnes & noble  29.99        4.777778
# 4                      computers  barnes & noble  89.55        4.319149
# 5                all electronics     a days tech  11.99        4.360000
# 6                      computers        kingston  33.97        4.571429
# 7                      computers       epartsdom  14.86        3.879397
# 8   portable audio & accessories  barnes & noble  58.88        3.875000
# 9      cell phones & accessories          cornmi  14.99        5.000000
# 10                     computers         sandisk  14.27        5.000000
# 11  portable audio & accessories  barnes & noble  14.95        4.666667
# 12                camera & photo         econmax  10.31        4.000000
# 13                     computers         sandisk  14.66        5.000000
# 14                     computers         sandisk  15.65        5.000000
# 15                     computers         sandisk  10.35        5.000000
# 16                     computers         sandisk  15.65        5.000000
# 17     cell phones & accessories  barnes & noble  18.95        5.000000
# 18                camera & photo          dazzne  10.20        5.000000
# 19                     computers         sandisk  16.45        3.714286
# 20                     computers        kingston  34.00        4.500000
#
#     rating_count     score
# 1           21.0  4.592462
# 2         1051.0  4.466763
# 3            9.0  4.303415
# 4           47.0  4.229878
# 5           25.0  4.193621
# 6            7.0  4.004269
# 7          199.0  3.860171
# 8           32.0  3.758611
# 9            3.0  3.758538
# 10           3.0  3.758538
# 11           3.0  3.508538
# 12           7.0  3.504269
# 13           2.0  3.344718
# 14           2.0  3.344718
# 15           2.0  3.344718
# 16           2.0  3.344718
# 17           2.0  3.344718
# 18           2.0  3.344718
# 19           7.0  3.254269
# 20           2.0  3.011384
