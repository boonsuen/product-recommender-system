# %% [markdown]
# # Reduce the size of the JSON file
# Since the device that we are using have limited memory, we create this notebook to reduce the file size by removing the column

# %%
#import library to be used in the project
import pandas as pd

#Read the split json file with dataframe
df = pd.read_json(r'C:\Users\Wilson Tan\Downloads\AI assignment\dataset\subset_meta_Electronics.json', lines=True)
df = pd.DataFrame(df)
df
# Out:
#                                                  category  \
# 0       [Electronics, Camera &amp; Photo, Video Survei...
# 1                       [Electronics, Camera &amp; Photo]
# 2       [Electronics, eBook Readers &amp; Accessories,...
# 3       [Electronics, eBook Readers & Accessories, eBo...
# 4       [Electronics, eBook Readers & Accessories, eBo...
# ...                                                   ...
# 104797  [Electronics, Camera & Photo, Accessories, Len...
# 104798  [Electronics, Computers & Accessories, Network...
# 104799  [Electronics, Camera & Photo, Lighting & Studi...
# 104800  [Electronics, Accessories & Supplies, Audio & ...
# 104801  [Electronics, Accessories & Supplies, Audio & ...
#
#                                                     tech1  \
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 104797
# 104798
# 104799
# 104800
# 104801   class="a-keyvalue prodDetTable" role="present...
#
# ...

# %%
#Print column
df.columns
# Out:
# Index(['category', 'tech1', 'description', 'fit', 'title', 'also_buy', 'tech2',
#        'brand', 'feature', 'rank', 'also_view', 'main_cat', 'similar_item',
#        'date', 'price', 'asin', 'imageURL', 'imageURLHighRes', 'details'],
#       dtype='object')

# %%
df.dtypes
# Out:
# category           object
# tech1              object
# description        object
# fit                object
# title              object
# also_buy           object
# tech2              object
# brand              object
# feature            object
# rank               object
# also_view          object
# main_cat           object
# similar_item       object
# date               object
# price              object
# asin               object
# imageURL           object
# imageURLHighRes    object
# details            object
# dtype: object

# %%
#Drop unneccesary column
df = df.drop(['category', 'tech1', 'description', 'fit', 'also_buy', 'tech2', 'brand', 'feature', 'rank', 
              'also_view', 'similar_item', 'date', 'price', 'imageURL','imageURLHighRes', 'details'], axis=1)
df
# Out:
#                                                     title            main_cat  \
# 0       Genuine Geovision 1 Channel 3rd Party NVR IP S...  Camera &amp; Photo
# 1       Books "Handbook of Astronomical Image Processi...  Camera &amp; Photo
# 2                                          One Hot Summer               Books
# 3       Hurray for Hattie Rabbit: Story and pictures (...               Books
# 4                          sex.lies.murder.fame.: A Novel               Books
# ...                                                   ...                 ...
# 104797  Precision Design EW-78BII Lens Hood for Canon ...      Camera & Photo
# 104798  NETGEAR RangeMax NEXT 802.11n (draft) Wireless...     All Electronics
# 104799               Polaroid 7&quot; Digital Photo Frame      Camera & Photo
# 104800  Monoprice 102081 HDMI Female to DVI-D Single L...           Computers
# 104801  Venture Horizon Media Storage Tower- Tall Doub...         Amazon Home
#
#               asin
# ...

# %%
#to json file with left column
df.to_json('test.json', orient='records', lines=True)

# %%
#Double Checking with the created json file
df = pd.read_json(r'C:\Users\Wilson Tan\Downloads\AI assignment\product_title.json', lines=True)
df.head()
# Out:
#                                                title            main_cat  \
# 0  Genuine Geovision 1 Channel 3rd Party NVR IP S...  Camera &amp; Photo
# 1  Books "Handbook of Astronomical Image Processi...  Camera &amp; Photo
# 2                                     One Hot Summer               Books
# 3  Hurray for Hattie Rabbit: Story and pictures (...               Books
# 4                     sex.lies.murder.fame.: A Novel               Books
#
#          asin
# 0  0011300000
# 1  0043396828
# 2  0060009810
# 3  0060219602
# 4  0060786817
